# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('meta_and_review.csv')

# %%
df.drop(['Unnamed: 0', ''], axis=1, inplace=True)
# Out:
#         Unnamed: 0        asin  \
# 0                0  1929099886
# 1                1  5357954771
# 2                2  5357954771
# 3                3  5357954771
# 4                4  5357954771
# ...            ...         ...
# 133161      133161  B00KNCOD26
# 133162      133162  B00KYCLTCM
# 133163      133163  B00KYCLTCM
# 133164      133164  B00KYWMYEE
# 133165      133165  B00L5YAROY
#
#                                                    review  overall helpful  \
# 0       this was a good buy great shampoo and conditio...      4.0  [0, 0]
# 1       i have used kms in the past and always loved t...      3.0  [0, 0]
# 2       i remember kms products being a prestige salon...      5.0  [0, 0]
# 3       this is a wonderful shampoo doesnt make your h...      5.0  [1, 1]
# 4       i have a very dry frizzy hair i have tried man...      5.0  [0, 0]
# ...                                                   ...      ...     ...
# ...

# %%
text_df = pd.DataFrame (columns= ['index', 'review'])
text_df.loc[:,'index'] = df.index
text_df.loc[:,'review'] = df.review

# %%
text_df.head()
# Out:
#    index                                             review
# 0      0  this was a good buy great shampoo and conditio...
# 1      1  i have used kms in the past and always loved t...
# 2      2  i remember kms products being a prestige salon...
# 3      3  this is a wonderful shampoo doesnt make your h...
# 4      4  i have a very dry frizzy hair i have tried man...

# %%
# Load libraries
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load data
SIA = SentimentIntensityAnalyzer()
text_df['polarity_score']=text_df.review.apply(lambda x:SIA.polarity_scores(str(x))['compound'])

# %%
text_df['neutral_score']=text_df.review.apply(lambda x:SIA.polarity_scores(str(x))['neu'])
text_df['negative_score']= text_df.review.apply(lambda x:SIA.polarity_scores(str(x))['neg'])
text_df['positive_score']= text_df.review.apply(lambda x:SIA.polarity_scores(str(x))['pos'])
#text_df['sentiment']=''
#text_df.loc[text_df.polarity_score>0,'sentiment']='POSITIVE'
#text_df.loc[text_df.polarity_score==0,'sentiment']='NEUTRAL'
#text_df.loc[text_df.polarity_score<0,'sentiment']='NEGATIVE'
text_df.head()
# Out:
#    index                                             review  polarity_score  \
# 0      0  this was a good buy great shampoo and conditio...          0.7783
# 1      1  i have used kms in the past and always loved t...          0.1546
# 2      2  i remember kms products being a prestige salon...          0.8316
# 3      3  this is a wonderful shampoo doesnt make your h...          0.9020
# 4      4  i have a very dry frizzy hair i have tried man...          0.8931
#
#    neutral_score  negative_score  positive_score
# 0          0.737           0.038           0.224
# 1          0.699           0.158           0.143
# 2          0.805           0.032           0.163
# 3          0.769           0.000           0.231
# 4          0.849           0.000           0.151

# %%
df = df.merge(text_df, left_index=True, right_index=True).rename(columns= {'review_x':'review'
                                                                     })
df.drop(['review_y', 'index'],axis=1,inplace=True)
#polarity: overall
#neural
#pos
#neg

# %%
sum(df.polarity_score.isnull())
# Out:
# 0

# %%
df.to_csv('meta_and_review_Overall_sentiment.csv', index=None)
